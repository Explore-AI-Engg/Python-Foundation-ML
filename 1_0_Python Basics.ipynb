# %% [markdown]
# ## Prnit Statement

# %%
print("Hello Explore - AI Engineering")
# Out:
# Hello Explore - AI Engineering

# %%
print('pytyhon is fun')
# Out:
# pytyhon is fun

# %%
print("Python Programing is fun" \
"and easy to learn")
# Out:
# Python Programing is funand easy to learn

# %% [markdown]
# ## Input Statement

# %%
user_input = input("Enter a value for x: ")
print("You entered:", user_input)
# Out:
# You entered: 33

# %% [markdown]
# ## varaibles ##

# %%
name = "Alice"
age = 30
is_Student = True
print(f"My name is {name} and I am {age} years old. is student: {is_Student}")
# Out:
# My name is Alice and I am 30 years old. is student: True

# %% [markdown]
# # DataTypes
#
#       integers (int)
#       floating Point (float)
#       string (str)
#       boolen - true False (bool)

# %%
x = "alice is a student"
print(x)
print(type(x))
# Out:
# alice is a student
# <class 'str'>

# %%
y = 10
print(y)
print(type(y))
# Out:
# 10
# <class 'int'>

# %%
z = 3.14
print(z)
print(type(z))
# Out:
# 3.14
# <class 'float'>

# %%
a = True
b = False
print(a)
print(b)
print(type(a))
print(type(b))
# Out:
# True
# False
# <class 'bool'>
# <class 'bool'>
