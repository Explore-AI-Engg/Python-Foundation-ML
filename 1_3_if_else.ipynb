# %% [markdown]
#  ## 1. Basic if Statement

# %% [markdown]
# if the condition is True
#
#       then Execute this Code block

# %%
age = 18 

# check if the Persion is 18 or older
if age >= 18:
    print("You are an adult.")
# Out:
# You are an adult.

# %%
if age >= 18:
    print("You are an adult.")
    print("You can vote.")
# Out:
# You are an adult.
# You can vote.

# %%
age = int(input("Enter your age: "))
if age >= 18:
    print("You are an adult.")
# Out:
# You are an adult.

# %% [markdown]
#  ## 2. if Else Statement

# %%
age = int(input("Enter your age: "))
if age >= 18:
    print("You are an adult.")
else:
    print("You are a minor.")
# Out:
# You are an adult.

# %% [markdown]
# ## 3. if elif else

# %%
marks = int(input("Enter your marks: "))
if marks >= 90:
    print("Grade: A")
elif marks >= 80:
    print("Grade: B")
elif marks >= 70:
    print("Grade: C")
# Out:
# Grade: B

# %% [markdown]
# # Nested If Else

# %%
age = int(input("Enter your age: "))
has_id = input("Do you have an ID? (yes/no): ").lower()
if age >= 18 and has_id == "yes":
    if age >= 60:
        print("You are eligible for senior citizen benefits.")
    else:
        print("Your young generation.")  
else:
    print("You cannot vote.")
# Out:
# Your young generation.

# %% [markdown]
# # 5.Combining Conditions with and / or

# %%
age = int (input("Enter your age: "))
has_ticket = input("Do you have a ticket? (yes/no): ").lower()

if age >= 18 and has_ticket == "yes":
    print("You can enter the concert.")
else:
    print("You must be at least 18 years old and have a ticket to enter the concert.")
# Out:
# You can enter the concert.
