# %% [markdown]
# # 1. Sumilated Error Log

# %%
num = int(input("Enter a number: "))
print("The square of the number is:", num ** 2)
# Out:
# The square of the number is: 4

# %%
# num = int(input("Enter a number: "))
# print("The square of the number is:", num ** 2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 num = int(input("Enter a number: "))
#       2 print("The square of the number is:", num ** 2)
#
# ValueError: invalid literal for int() with base 10: 'sfgsfg'

# %% [markdown]
# # 2. Using try and except blocks to handle exceptions

# %%
try: 
    num = int(input("Enter a number: "))
    print("The square of the number is:", num ** 2)
except ValueError:
    print("Invalid input. Please enter a valid number.")
# Out:
# Invalid input. Please enter a valid number.

# %% [markdown]
# # Catching any Errors

# %%
try :
    num = int(input("Enter a number: "))
    result = 10 / num   
    print("The square of the number is:", num ** 2)  
except Exception as e:
    print("An error occurred:", str(e))
# Out:
# An error occurred: invalid literal for int() with base 10: 'er'

# %% [markdown]
# # multiple Exception

# %%
try :
    num = int(input("Enter a number: "))
    result = 10 / num   
    print("The square of the number is:", num ** 2)
except ValueError:
    print("Invalid input. Please enter a valid number.")
except ZeroDivisionError:
    print("Cannot divide by zero. Please enter a non-zero number.")   
except Exception as e:
    print("An error occurred:", str(e))
# Out:
# The square of the number is: 16

# %% [markdown]
# ## 5. Finally Block

# %%
try:
    num = int(input("Enter a number: "))
    print("The square of the number is:", num ** 2)
except ValueError:
    print("Invalid input. Please enter a valid number.")
finally:
    print("This block runs regardless of whether an exception occurred or not.")
# Out:
# The square of the number is: 36
# This block runs regardless of whether an exception occurred or not.
