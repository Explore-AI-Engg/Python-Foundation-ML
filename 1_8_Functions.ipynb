# %% [markdown]
# ### 1. Create a Simple function

# %%
# define great function
def great():  
    print("Hello, World!")

# %%
great()
# Out:
# Hello, World!

# %%
great()
# Out:
# Hello, World!

# %% [markdown]
# ### 2. function with parameters

# %%
def great_user(name):  
    print("Hello, " + name + "!")

# %%
great_user("Alice")
# Out:
# Hello, Alice!

# %%
great_user(name = "Alice_smith")
# Out:
# Hello, Alice_smith!

# %%
def add(a, b):
  result = a + b
  print("This will never be printed ", result)

# %%
add(a=5, b=3)
# Out:
# This will never be printed  8

# %%
def square(x):
  return x * x  

result = square(4)
print("the square is ", result)

#you can also print the result directly
print("the square is ", square(4))
# Out:
# the square is  16
# the square is  16

# %%
add(a =100, b = 200)
# Out:
# This will never be printed  300

# %%
add(5, 3)
# Out:
# This will never be printed  8

# %%
x = 10 

def add(a, b):
  output = a + b
  print("The sum is ", output)
  print("The value of x is ", x)

# %%
add(5, 3)
# Out:
# The sum is  8
# The value of x is  10

# %%
print(output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 print(output)
#
# NameError: name 'output' is not defined
